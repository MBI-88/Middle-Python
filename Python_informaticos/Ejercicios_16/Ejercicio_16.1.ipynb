# %% [markdown]
# Escribe un programa que recorra un directorio  y todos sus subdirectorios, buscando los archivos
# que tengan un sufijo  determinado (como MP3) y liste las parejas de ficheros que tengan el mismo
# tamaño.

# %%
import os 

def buscar_dir(direccion):
    diccionario={}
    directorios=0
    for dispahts,dirs,filesname in os.walk(direccion):
        for  nombre_file in filesname:
            if nombre_file.endswith('.mp3') and len(nombre_file)>0:
                ruta=os.path.join(dispahts,nombre_file)
                peso=os.path.getsize(ruta)
                if peso in diccionario.keys():
                    print('Peso= {} Archivo_nuevo= {} Archivo_diccionario= {}'.format(peso,ruta,diccionario[peso]))
                    
                else:
                    diccionario[peso]=ruta
                    directorios=len(dirs)
            else:
                continue
    return diccionario
# Main()
try:

    direccion=input('Direccion:__')
    if os.path.isdir(direccion):
        print(buscar_dir(direccion)) 
    else:
        print('Error en la direccion')
except:
    print('El sistema no puede  encontrar  el directorio')
# Out:
# Direccion:__F:/Almacenamiento/Musica
# Peso= 3671102 Archivo_nuevo= F:/Almacenamiento/Musica\! Especial Semanal de lo + Pegao\07-Lazaro Diaz -Saludate la Mia [Dir EJE RECORDS].mp3 Archivo_diccionario= F:/Almacenamiento/Musica\! Especial Semanal de lo + Pegao\06-Lazaro Diaz -Saludate la Mia [Dir EJE RECORDS].mp3
# Peso= 4168473 Archivo_nuevo= F:/Almacenamiento/Musica\! Especial Semanal de lo + Pegao\10-SI TU NO ESTAS(Harrison x Bombero x Mono x Narr1tell)(DIAMANTE RECORDS).mp3 Archivo_diccionario= F:/Almacenamiento/Musica\! Especial Semanal de lo + Pegao\01-SI TU NO ESTAS(Harrison x Bombero x Mono x Narr1tell)(DIAMANTE RECORDS).mp3
# Peso= 4178672 Archivo_nuevo= F:/Almacenamiento/Musica\! Top de Octubre Internacional\Daddy Yankee 🐝 Rkm & Ken-Y 🐝 Arcangel 🐝🍯 - Zum Zum [Official Video].mp3 Archivo_diccionario= F:/Almacenamiento/Musica\! Top de Octubre Internacional\Daddy Yankee .mp3
# Peso= 3582244 Archivo_nuevo= F:/Almacenamiento/Musica\! Top de Septiembre Internacional\Arcangel Rey Chavez ,  Dime Por Que [Official Video].mp3 Archivo_diccionario= F:/Almacenamiento/Musica\! Top de Octubre Internacional\Arcangel Rey Chavez ,  Dime Por Que [Official Video].mp3
# Peso= 3672037 Archivo_nuevo= F:/Almacenamiento/Musica\!Discografia -[La Oreja de Van Gogh]\La Oreja de Van Gogh - Cometas Por El Cielo 2011\El Tiempo A Solas.mp3 Archivo_diccionario= F:/Almacenamiento/Musica\!Discografia -[La Oreja de Van Gogh]\La Oreja de Van Gogh - Cometas Por El Cielo 2011\Día Cero.mp3
 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\05-EGF MUSIC -Gatica loca [Prod DJ UNIC][Dir EJE RECORDS].mp3', 3811954: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\05-YD Ft Pablo Barrera(Alejate de mi).mp3', 3024937: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\05-Yomil N Dany -CHONA.mp3', 2564346: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\06-EL ENVIADO % DJUNIC -TORTOLITO .mp3', 3216780: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\06-Lady Gaga - Look What I Found (A Star Is Born).mp3', 3671102: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\06-Lazaro Diaz -Saludate la Mia [Dir EJE RECORDS].mp3', 3985407: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\07--AMNESIA -LADY LAURA FT EL TAIGER.mp3', 3335063: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\07-BAILAME ASI -ZAYLON X EL TASIS.mp3', 3121485: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\07-Big Junior X Young Poet  -Caminos separados [Prod DJ UNIC][Dir EJE RECORDS].mp3', 2897877: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\07-Jaleo - Nicky Jam X Steve Aoki.mp3', 4170563: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\07-No hables mas de mi -NARR1TELL feat HALLOWEEN [Dir EJE RECORDS].mp3', 4000036: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\08-Martin Garrix & Pierce Fulton feat. Mike Shinoda - Waiting For Tomorrow (Official Video).mp3', 4288010: 'F:/Almacenamiento/Musica\\! Especial Semanal de lo + Pegao\\09-Yenddi, Abraham Mateo Feat. De La Ghetto + Jon Z  - Bom Bom (Official Video).mp3', 3523144: 'F:/Almacenamiento/Musica\\! Especial Semanal de ...

# %% [markdown]
# Modificar el programa anterior  para buscar ficheros que tengan contenidos duplicados usando un algoritmo de hashing o cheksum

# %%
import os  
import hashlib as has

def buscar_dir(direccion):
    diccionario={}
    directorios=0
    for dispahts,dirs,filesname in os.walk(direccion):
        for  nombre_file in filesname:
                ruta=os.path.join(dispahts,nombre_file)
                try:
                    with open(ruta,'r') as fname:
                            datos=fname.read()
                            fname.close()
                            cheksum= has.md5(datos.encode()).hexdigest()
                            if cheksum in diccionario.keys():
                                 print(ruta,'  ',diccionario[cheksum])

                            else:
                                diccionario[cheksum]=ruta
                except:
                    print('No se pudo abrir el archivo')
                      
           
    return diccionario

# Main()
directorio=input('Directorio a buscar')
if os.path.isdir(directorio):
    buscar_dir(directorio)
else:
    print('La entrada no es un directorio')
# Out:
# Directorio a buscarC:/Users/MBI/Documents/Python_Scripts/Data_Set_Entrenamiento
# C:/Users/MBI/Documents/Python_Scripts/Data_Set_Entrenamiento\datos_misteriosos.csv    C:/Users/MBI/Documents/Python_Scripts/Data_Set_Entrenamiento\054 datos-misteriosos.csv
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# No se pudo abrir el archivo
# C:/Users/MBI/Documents/Python_Scripts/Data_Set_Entrenamiento\vehiculos_original.csv    C:/Users/MBI/Documents/Python_Scripts/Data_Set_Entrenamiento\071 vehiculos-original.csv
# No se pudo abrir el archivo
